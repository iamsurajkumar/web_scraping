# %% [markdown]
# # Web Scrapping
# ## S&P 100 Wiki and 10-K SEC EDGARS forms of Apple and Intel
#
#
# **Suraj Kumar**
#
# **Current Job** \
# *Big Data Model Developer @ American Express*
#
# **Post Graduation**
# *MA Economics(Final Year)*
# *Department of Economics*
# **Delhi School of Economics**
# *India*
#
# **Under graduation**
# *B.Tech in Civil Engineering from __Indian Institute of Technology, Delhi (IIT Delhi)__*

# %% [markdown]
# ## Introduction
#
# This notebook contains the python code to complete a coding assignment given by *Prof. John Gallemore*. The assignment mainly testes out the coding skill of the candidate with regard to web scrapping.
#
# **Task 1: Description**\
# In this python package *requests* has been used to retrieve a table of S&P 100 companies from their wikipedia page. After retreiving the table, the company name columns is fuzzy matched with set of company names from from local gvkeys.csv file by using python *fuzzywuzzy* package.
#
# **Task 2:Description**\
# In this task, 10-K Forms of Intel and Apple for the fiscal years of 2014 to 2018 have been retrieved from SEC EDGAR website. The the next step, Risk Section portion of the 10-K form is analyzed to get the following information
#
# 1. The number of words in *Risk Section*
# 2. The number of times the word "competition" repeats in the *Risk Section*.
# 3. Exports the text of *Risk Section* to txt file
# 4. Python package *nltk* is used to remove all the stopwords
# 5. Notes occurence of the word *patents* and its variation such as patenting, patents, etc. It notes each repetition as word preceding, occurence found and word following.

# %% [markdown]
# ##  Task 1: Retriving Data from S&P 100 wikipedia page

# %%
# importing libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
#import re # importing regex
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
 


# Setting up options on display of row and columns in Pandas data frame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_colwidth',-1)

## To output multiple objects in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\suraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\suraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# retriving the data from the website

## defining the url
url = "https://en.wikipedia.org/wiki/S%26P_100"

## retriving the url
r = requests.get(url)

# %%
## Checking the status of the request
r.status_code

# 200 means success
# Out:
# 200

# %%
# converting to text
html_doc = r.text

# %%
# printing the html doc
#print(html_doc)

# converting to Beautiful Soup format

html_doc_soup = BeautifulSoup(html_doc)

# %%
#html_doc_soup

# %%
# Extracting the table of companies
table = html_doc_soup.find('table',{'class':'wikitable sortable'})
#table = soup.find('table', {'class': 'details'})

# %%
#table

# %%
# Defining the firms table

pd_firms = pd.DataFrame(columns = ['Symbol','Name','Link'])

# %%
pd_firms
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Link]
# Index: []

# %%
#pd_firms.at[0,'Symbol'] = 'a'
pd_firms
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Link]
# Index: []

# %%
row_marker = 0
for row in table.find_all('tr'):
    columns = row.find_all('td')
    # Filter so as to not run the following commands on the first element of the 
    # row as it contains only 'th' tags so find_all('td') will be null.
    if(len(columns)!= 0): 
        # Getting the Symbol
        symbol_cell = columns[0]
        pd_firms.at[row_marker,'Symbol'] = symbol_cell.get_text().rstrip()
        
        # Extracing the tag from the the second element in column list
        name_and_link_tag_cell = columns[1].find_all('a')[0]
        
        # Getting the Name
        pd_firms.at[row_marker,'Name'] = name_and_link_tag_cell.get('title')

        # Getting the link
        pd_firms.at[row_marker,'Link'] = "https://en.wikipedia.org"+name_and_link_tag_cell.get('href')
        row_marker = row_marker + 1
    
    #print(row_marker)
pd_firms
# Out:
#     Symbol                          Name  \
# 0    AAPL   Apple Inc.
# 1    ABBV   AbbVie Inc.
# 2    ABT    Abbott Laboratories
# 3    ACN    Accenture
# 4    ADBE   Adobe Inc.
# 5    AGN    Allergan
# 6    AIG    American International Group
# 7    ALL    Allstate
# 8    AMGN   Amgen
# 9    AMZN   Amazon.com
# 10   AXP    American Express
# 11   BA     Boeing
# 12   BAC    Bank of America
# 13   BIIB   Biogen
# 14   BK     The Bank of New York Mellon
# 15   BKNG   Booking Holdings
# 16   BLK    BlackRock
# 17   BMY    Bristol-Myers Squibb
# 18   BRK.B  Berkshire Hathaway
# 19   C      Citigroup
# 20   CAT    Caterpillar Inc.
# 21   CELG   Celgene
# 22   CHTR   Charter Communications
# 23   CL     Colgate-Palmolive
# 24   CMCSA  Comcast
# 25   COF    Capital One
# 26   COP    ConocoPhillips
# 27   COST   Costco Wholesale Corp.
# 28   CSCO   Cisco Systems
# 29   CVS    CVS Health
# 30   CVX    Chevron Corporation
# 31   DD     DuPont de Nemours Inc
# 32   DHR    Danaher Corporation
# 33   DIS    The Walt Disney Company
# 34   DOW    Dow Inc.
# 35   DUK    Duke Energy
# 36   EMR    Emerson Electric
# 37   EXC    Exelon
# 38   F      Ford Motor Company
# 39   FB     Facebook
# 40   FDX    FedEx
# 41   GD     General Dynamics
# 42   GE     General Electric
# 43   GILD   Gilead Sciences
# 44   GM     General Motors
# 45   GOOG   Alphabet Inc.
# 46   GOOGL  Alphabet Inc.
# 47   GS     Goldman Sachs
# 48   HD     Home Depot
# 49   HON    Honeywell
# 50   IBM    IBM
# 51   INTC   Intel
# 52   JNJ    Johnson & Johnson
# 53   JPM    JPMorgan Chase & Co.
# 54   KHC    Kraft Heinz
# 55   KMI    Kinder Morgan
# 56   KO     The Coca-Cola Company
# 57   LLY    Eli Lilly and Company
# 58   LMT    Lockheed Martin
# 59   LOW    Lowe's
# 60   MA     MasterCard
# 61   MCD    McDonald's
# 62   MDLZ   Mondelēz International
# 63   MDT    Medtronic
# 64   MET    MetLife
# 65   MMM    3M
# 66   MO     Altria
# 67   MRK    Merck & Co.
# 68   MS     Morgan Stanley
# 69   MSFT   Microsoft
# 70   NEE    NextEra Energy
# 71   NFLX   Netflix
# 72   NKE    Nike, Inc.
# 73   NVDA   Nvidia
# 74   ORCL   Oracle Corporation
# 75   OXY    Occidental Petroleum
# 76   PEP    PepsiCo
# 77   PFE    Pfizer Inc
# 78   PG     Procter & Gamble
# 79   PM     Philip Morris International
# 80   PYPL   PayPal
# 81   QCOM   Qualcomm
# 82   RTN    Raytheon
# 83   SBUX   Starbucks
# 84   SLB    Schlumberger
# 85   SO     Southern Company
# 86   SPG    Simon Property Group
# 87   T      AT&T
# 88   TGT    Target Corporation
# 89   TXN    Texas Instruments
# 90   UNH    UnitedHealth Group
# 91   UNP    Union Pacific Corporation
# 92   UPS    United Parcel Service
# 93   USB    U.S. Bancorp
# 94   UTX    United Technologies
# 95   V      Visa Inc.
# 96   VZ     Verizon Communications
# 97   WBA    Walgreens Boots Alliance
# 98   WFC    Wells Fargo
# 99   WMT    Walmart
# 100  XOM    ExxonMobil
#
#                                                            Link
# 0    https://en.wikipedia.org/wiki/Apple_Inc.
# 1    https://en.wikipedia.org/wiki/AbbVie_Inc.
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3    https://en.wikipedia.org/wiki/Accenture
# 4    https://en.wikipedia.org/wiki/Adobe_Inc.
# 5    https://en.wikipedia.org/wiki/Allergan
# 6    https://en.wikipedia.org/wiki/American_International_Group
# 7    https://en.wikipedia.org/wiki/Allstate
# 8    https://en.wikipedia.org/wiki/Amgen
# 9    https://en.wikipedia.org/wiki/Amazon.com
# 10   https://en.wikipedia.org/wiki/American_Express
# 11   https://en.wikipedia.org/wiki/Boeing
# 12   https://en.wikipedia.org/wiki/Bank_of_America
# 13   https://en.wikipedia.org/wiki/Biogen
# 14   https://en.wikipedia.org/wiki/The_Bank_of_New_York_Mellon
# 15   https://en.wikipedia.org/wiki/Booking_Holdings
# 16   https://en.wikipedia.org/wiki/BlackRock
# 17   https://en.wikipedia.org/wiki/Bristol-Myers_Squibb
# 18   https://en.wikipedia.org/wiki/Berkshire_Hathaway
# 19   https://en.wikipedia.org/wiki/Citigroup
# 20   https://en.wikipedia.org/wiki/Caterpillar_Inc.
# 21   https://en.wikipedia.org/wiki/Celgene
# 22   https://en.wikipedia.org/wiki/Charter_Communications
# 23   https://en.wikipedia.org/wiki/Colgate-Palmolive
# 24   https://en.wikipedia.org/wiki/Comcast
# 25   https://en.wikipedia.org/wiki/Capital_One
# 26   https://en.wikipedia.org/wiki/ConocoPhillips
# 27   https://en.wikipedia.org/wiki/Costco_Wholesale_Corp.
# 28   https://en.wikipedia.org/wiki/Cisco_Systems
# 29   https://en.wikipedia.org/wiki/CVS_Health
# 30   https://en.wikipedia.org/wiki/Chevron_Corporation
# 31   https://en.wikipedia.org/wiki/DuPont_de_Nemours_Inc
# 32   https://en.wikipedia.org/wiki/Danaher_Corporation
# 33   https://en.wikipedia.org/wiki/The_Walt_Disney_Company
# 34   https://en.wikipedia.org/wiki/Dow_Inc.
# 35   https://en.wikipedia.org/wiki/Duke_Energy
# 36   https://en.wikipedia.org/wiki/Emerson_Electric
# 37   https://en.wikipedia.org/wiki/Exelon
# 38   https://en.wikipedia.org/wiki/Ford_Motor_Company
# 39   https://en.wikipedia.org/wiki/Facebook
# 40   https://en.wikipedia.org/wiki/FedEx
# 41   https://en.wikipedia.org/wiki/General_Dynamics
# 42   https://en.wikipedia.org/wiki/General_Electric
# 43   https://en.wikipedia.org/wiki/Gilead_Sciences
# 44   https://en.wikipedia.org/wiki/General_Motors
# 45   https://en.wikipedia.org/wiki/Alphabet_Inc.
# 46   https://en.wikipedia.org/wiki/Alphabet_Inc.
# 47   https://en.wikipedia.org/wiki/Goldman_Sachs
# 48   https://en.wikipedia.org/wiki/Home_Depot
# 49   https://en.wikipedia.org/wiki/Honeywell
# 50   https://en.wikipedia.org/wiki/IBM
# 51   https://en.wikipedia.org/wiki/Intel
# 52   https://en.wikipedia.org/wiki/Johnson_%26_Johnson
# 53   https://en.wikipedia.org/wiki/JPMorgan_Chase_%26_Co.
# 54   https://en.wikipedia.org/wiki/Kraft_Heinz
# 55   https://en.wikipedia.org/wiki/Kinder_Morgan
# 56   https://en.wikipedia.org/wiki/The_Coca-Cola_Company
# 57   https://en.wikipedia.org/wiki/Eli_Lilly_and_Company
# 58   https://en.wikipedia.org/wiki/Lockheed_Martin
# 59   https://en.wikipedia.org/wiki/Lowe%27s
# 60   https://en.wikipedia.org/wiki/MasterCard
# 61   https://en.wikipedia.org/wiki/McDonald%27s
# 62   https://en.wikipedia.org/wiki/Mondel%C4%93z_International
# 63   https://en.wikipedia.org/wiki/Medtronic
# 64   https://en.wikipedia.org/wiki/MetLife
# 65   https://en.wikipedia.org/wiki/3M
# 66   https://en.wikipedia.org/wiki/Altria
# 67   https://en.wikipedia.org/wiki/Merck_%26_Co.
# 68   https://en.wikipedia.org/wiki/Morgan_Stanley
# 69   https://en.wikipedia.org/wiki/Microsoft
# 70   https://en.wikipedia.org/wiki/NextEra_Energy
# 71   https://en.wikipedia.org/wiki/Netflix
# 72   https://en.wikipedia.org/wiki/Nike,_Inc.
# 73   https://en.wikipedia.org/wiki/Nvidia
# 74   https://en.wikipedia.org/wiki/Oracle_Corporation
# 75   https://en.wikipedia.org/wiki/Occidental_Petroleum
# 76   https://en.wikipedia.org/wiki/PepsiCo
# 77   https://en.wikipedia.org/wiki/Pfizer_Inc
# 78   https://en.wikipedia.org/wiki/Procter_%26_Gamble
# 79   https://en.wikipedia.org/wiki/Philip_Morris_International
# 80   https://en.wikipedia.org/wiki/PayPal
# 81   https://en.wikipedia.org/wiki/Qualcomm
# 82   https://en.wikipedia.org/wiki/Raytheon
# 83   https://en.wikipedia.org/wiki/Starbucks
# 84   https://en.wikipedia.org/wiki/Schlumberger
# 85   https://en.wikipedia.org/wiki/Southern_Company
# 86   https://en.wikipedia.org/wiki/Simon_Property_Group
# 87   https://en.wikipedia.org/wiki/AT%26T
# 88   https://en.wikipedia.org/wiki/Target_Corporation
# 89   https://en.wikipedia.org/wiki/Texas_Instruments
# 90   https://en.wikipedia.org/wiki/UnitedHealth_Group
# 91   https://en.wikipedia.org/wiki/Union_Pacific_Corporation
# 92   https://en.wikipedia.org/wiki/United_Parcel_Service
# 93   https://en.wikipedia.org/wiki/U.S._Bancorp
# 94   https://en.wikipedia.org/wiki/United_Technologies
# 95   https://en.wikipedia.org/wiki/Visa_Inc.
# 96   https://en.wikipedia.org/wiki/Verizon_Communications
# 97   https://en.wikipedia.org/wiki/Walgreens_Boots_Alliance
# 98   https://en.wikipedia.org/wiki/Wells_Fargo
# 99   https://en.wikipedia.org/wiki/Walmart
# 100  https://en.wikipedia.org/wiki/ExxonMobil

# %%
## importing the gvkeys.csv now
gvkeys_df = pd.read_csv("names_gvkeys.csv")

# Checking number of columns and rows
gvkeys_df.shape
# Out:
# (112086, 2)

# %%
# Checking the head
gvkeys_df.head(11)

# Removing the duplicates in gvkeys dataframe
gvkeys_nodup_df = gvkeys_df.drop_duplicates()

# Checking the shape of this dataframe
gvkeys_nodup_df.shape

# Checking the head
gvkeys_nodup_df.head(10)
# Out:
#     gvkey                         conm
# 0   1004   AAR CORP
# 1   1004   AAR CORP
# 2   1004   AAR CORP
# 3   1004   AAR CORP
# 4   1004   AAR CORP
# 5   1004   AAR CORP
# 6   1004   AAR CORP
# 7   1004   AAR CORP
# 8   1004   AAR CORP
# 9   1013   ADC TELECOMMUNICATIONS INC
# 10  1045   AMERICAN AIRLINES GROUP INC
# (16876, 2)
#     gvkey                          conm
# 0   1004   AAR CORP
# 9   1013   ADC TELECOMMUNICATIONS INC
# 10  1045   AMERICAN AIRLINES GROUP INC
# 19  1050   CECO ENVIRONMENTAL CORP
# 28  1062   ASA GOLD AND PRECIOUS METALS
# 46  1072   AVX CORP
# 56  1075   PINNACLE WEST CAPITAL CORP
# 65  1076   AARON'S INC
# 74  1078   ABBOTT LABORATORIES
# 83  1082   SERVIDYNE INC

# %%
# Checking for Unique Counts
gvkeys_nodup_df.nunique()


# Reseting the index of gvkeys_nodup_df
gvkeys_nodup_df = gvkeys_nodup_df.reset_index()
gvkeys_nodup_df.head()
# Out:
# gvkey    16876
# conm     16876
# dtype: int64
#    index  gvkey                          conm
# 0  0      1004   AAR CORP
# 1  9      1013   ADC TELECOMMUNICATIONS INC
# 2  10     1045   AMERICAN AIRLINES GROUP INC
# 3  19     1050   CECO ENVIRONMENTAL CORP
# 4  28     1062   ASA GOLD AND PRECIOUS METALS

# %%
# Adding addtional columns to pd_firms dataframe

pd_firms['matched_company_name'] = ''
pd_firms['score'] = np.nan

# Checking the head
pd_firms.head()
# Out:
#   Symbol                 Name  \
# 0  AAPL   Apple Inc.
# 1  ABBV   AbbVie Inc.
# 2  ABT    Abbott Laboratories
# 3  ACN    Accenture
# 4  ADBE   Adobe Inc.
#
#                                                 Link matched_company_name  \
# 0  https://en.wikipedia.org/wiki/Apple_Inc.
# 1  https://en.wikipedia.org/wiki/AbbVie_Inc.
# 2  https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3  https://en.wikipedia.org/wiki/Accenture
# 4  https://en.wikipedia.org/wiki/Adobe_Inc.
#
#    score
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
number_of_firms_in_SP100 = pd_firms.shape[0]
number_of_firms_in_SP100
#Strange its 101 when it should be 100
# Out:
# 101

# %%
# Consedring the company names from gvkeys dataframe

strOptions = gvkeys_nodup_df['conm']

# %%
# This loop could have been paralel parallelized given more time
# Running a For Loop to Assign values from gvkeys_nodup_df into pd_firms dataframe
for i in range(number_of_firms_in_SP100):
    str2Match = pd_firms.iloc[i,1]
    
    # Getting the best match
    highest = process.extractOne(str2Match,strOptions)
    highest_index = highest[2]
    
    # Extracting the matched company name and score using the index from highest tuple
    matched_name = gvkeys_nodup_df['conm'].iloc[highest_index]
    score = gvkeys_nodup_df['gvkey'].iloc[highest_index]
    
    # Setting the values in pd_firms dataframe
    pd_firms.at[i,'matched_company_name'] = matched_name
    pd_firms.at[i,'score'] = score
    #print(str2Match)

# %%
# Looking at the dataframe
pd_firms
# Out:
#     Symbol                          Name  \
# 0    AAPL   Apple Inc.
# 1    ABBV   AbbVie Inc.
# 2    ABT    Abbott Laboratories
# 3    ACN    Accenture
# 4    ADBE   Adobe Inc.
# 5    AGN    Allergan
# 6    AIG    American International Group
# 7    ALL    Allstate
# 8    AMGN   Amgen
# 9    AMZN   Amazon.com
# 10   AXP    American Express
# 11   BA     Boeing
# 12   BAC    Bank of America
# 13   BIIB   Biogen
# 14   BK     The Bank of New York Mellon
# 15   BKNG   Booking Holdings
# 16   BLK    BlackRock
# 17   BMY    Bristol-Myers Squibb
# 18   BRK.B  Berkshire Hathaway
# 19   C      Citigroup
# 20   CAT    Caterpillar Inc.
# 21   CELG   Celgene
# 22   CHTR   Charter Communications
# 23   CL     Colgate-Palmolive
# 24   CMCSA  Comcast
# 25   COF    Capital One
# 26   COP    ConocoPhillips
# 27   COST   Costco Wholesale Corp.
# 28   CSCO   Cisco Systems
# 29   CVS    CVS Health
# 30   CVX    Chevron Corporation
# 31   DD     DuPont de Nemours Inc
# 32   DHR    Danaher Corporation
# 33   DIS    The Walt Disney Company
# 34   DOW    Dow Inc.
# 35   DUK    Duke Energy
# 36   EMR    Emerson Electric
# 37   EXC    Exelon
# 38   F      Ford Motor Company
# 39   FB     Facebook
# 40   FDX    FedEx
# 41   GD     General Dynamics
# 42   GE     General Electric
# 43   GILD   Gilead Sciences
# 44   GM     General Motors
# 45   GOOG   Alphabet Inc.
# 46   GOOGL  Alphabet Inc.
# 47   GS     Goldman Sachs
# 48   HD     Home Depot
# 49   HON    Honeywell
# 50   IBM    IBM
# 51   INTC   Intel
# 52   JNJ    Johnson & Johnson
# 53   JPM    JPMorgan Chase & Co.
# 54   KHC    Kraft Heinz
# 55   KMI    Kinder Morgan
# 56   KO     The Coca-Cola Company
# 57   LLY    Eli Lilly and Company
# 58   LMT    Lockheed Martin
# 59   LOW    Lowe's
# 60   MA     MasterCard
# 61   MCD    McDonald's
# 62   MDLZ   Mondelēz International
# 63   MDT    Medtronic
# 64   MET    MetLife
# 65   MMM    3M
# 66   MO     Altria
# 67   MRK    Merck & Co.
# 68   MS     Morgan Stanley
# 69   MSFT   Microsoft
# 70   NEE    NextEra Energy
# 71   NFLX   Netflix
# 72   NKE    Nike, Inc.
# 73   NVDA   Nvidia
# 74   ORCL   Oracle Corporation
# 75   OXY    Occidental Petroleum
# 76   PEP    PepsiCo
# 77   PFE    Pfizer Inc
# 78   PG     Procter & Gamble
# 79   PM     Philip Morris International
# 80   PYPL   PayPal
# 81   QCOM   Qualcomm
# 82   RTN    Raytheon
# 83   SBUX   Starbucks
# 84   SLB    Schlumberger
# 85   SO     Southern Company
# 86   SPG    Simon Property Group
# 87   T      AT&T
# 88   TGT    Target Corporation
# 89   TXN    Texas Instruments
# 90   UNH    UnitedHealth Group
# 91   UNP    Union Pacific Corporation
# 92   UPS    United Parcel Service
# 93   USB    U.S. Bancorp
# 94   UTX    United Technologies
# 95   V      Visa Inc.
# 96   VZ     Verizon Communications
# 97   WBA    Walgreens Boots Alliance
# 98   WFC    Wells Fargo
# 99   WMT    Walmart
# 100  XOM    ExxonMobil
#
#                                                            Link  \
# 0    https://en.wikipedia.org/wiki/Apple_Inc.
# 1    https://en.wikipedia.org/wiki/AbbVie_Inc.
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3    https://en.wikipedia.org/wiki/Accenture
# 4    https://en.wikipedia.org/wiki/Adobe_Inc.
# 5    https://en.wikipedia.org/wiki/Allergan
# 6    https://en.wikipedia.org/wiki/American_International_Group
# 7    https://en.wikipedia.org/wiki/Allstate
# 8    https://en.wikipedia.org/wiki/Amgen
# 9    https://en.wikipedia.org/wiki/Amazon.com
# 10   https://en.wikipedia.org/wiki/American_Express
# 11   https://en.wikipedia.org/wiki/Boeing
# 12   https://en.wikipedia.org/wiki/Bank_of_America
# 13   https://en.wikipedia.org/wiki/Biogen
# 14   https://en.wikipedia.org/wiki/The_Bank_of_New_York_Mellon
# 15   https://en.wikipedia.org/wiki/Booking_Holdings
# 16   https://en.wikipedia.org/wiki/BlackRock
# 17   https://en.wikipedia.org/wiki/Bristol-Myers_Squibb
# 18   https://en.wikipedia.org/wiki/Berkshire_Hathaway
# 19   https://en.wikipedia.org/wiki/Citigroup
# 20   https://en.wikipedia.org/wiki/Caterpillar_Inc.
# 21   https://en.wikipedia.org/wiki/Celgene
# 22   https://en.wikipedia.org/wiki/Charter_Communications
# 23   https://en.wikipedia.org/wiki/Colgate-Palmolive
# 24   https://en.wikipedia.org/wiki/Comcast
# 25   https://en.wikipedia.org/wiki/Capital_One
# 26   https://en.wikipedia.org/wiki/ConocoPhillips
# 27   https://en.wikipedia.org/wiki/Costco_Wholesale_Corp.
# 28   https://en.wikipedia.org/wiki/Cisco_Systems
# 29   https://en.wikipedia.org/wiki/CVS_Health
# 30   https://en.wikipedia.org/wiki/Chevron_Corporation
# 31   https://en.wikipedia.org/wiki/DuPont_de_Nemours_Inc
# 32   https://en.wikipedia.org/wiki/Danaher_Corporation
# 33   https://en.wikipedia.org/wiki/The_Walt_Disney_Company
# 34   https://en.wikipedia.org/wiki/Dow_Inc.
# 35   https://en.wikipedia.org/wiki/Duke_Energy
# 36   https://en.wikipedia.org/wiki/Emerson_Electric
# 37   https://en.wikipedia.org/wiki/Exelon
# 38   https://en.wikipedia.org/wiki/Ford_Motor_Company
# 39   https://en.wikipedia.org/wiki/Facebook
# 40   https://en.wikipedia.org/wiki/FedEx
# 41   https://en.wikipedia.org/wiki/General_Dynamics
# 42   https://en.wikipedia.org/wiki/General_Electric
# 43   https://en.wikipedia.org/wiki/Gilead_Sciences
# 44   https://en.wikipedia.org/wiki/General_Motors
# 45   https://en.wikipedia.org/wiki/Alphabet_Inc.
# 46   https://en.wikipedia.org/wiki/Alphabet_Inc.
# 47   https://en.wikipedia.org/wiki/Goldman_Sachs
# 48   https://en.wikipedia.org/wiki/Home_Depot
# 49   https://en.wikipedia.org/wiki/Honeywell
# 50   https://en.wikipedia.org/wiki/IBM
# 51   https://en.wikipedia.org/wiki/Intel
# 52   https://en.wikipedia.org/wiki/Johnson_%26_Johnson
# 53   https://en.wikipedia.org/wiki/JPMorgan_Chase_%26_Co.
# 54   https://en.wikipedia.org/wiki/Kraft_Heinz
# 55   https://en.wikipedia.org/wiki/Kinder_Morgan
# 56   https://en.wikipedia.org/wiki/The_Coca-Cola_Company
# 57   https://en.wikipedia.org/wiki/Eli_Lilly_and_Company
# 58   https://en.wikipedia.org/wiki/Lockheed_Martin
# 59   https://en.wikipedia.org/wiki/Lowe%27s
# 60   https://en.wikipedia.org/wiki/MasterCard
# 61   https://en.wikipedia.org/wiki/McDonald%27s
# 62   https://en.wikipedia.org/wiki/Mondel%C4%93z_International
# 63   https://en.wikipedia.org/wiki/Medtronic
# 64   https://en.wikipedia.org/wiki/MetLife
# 65   https://en.wikipedia.org/wiki/3M
# 66   https://en.wikipedia.org/wiki/Altria
# 67   https://en.wikipedia.org/wiki/Merck_%26_Co.
# 68   https://en.wikipedia.org/wiki/Morgan_Stanley
# 69   https://en.wikipedia.org/wiki/Microsoft
# 70   https://en.wikipedia.org/wiki/NextEra_Energy
# 71   https://en.wikipedia.org/wiki/Netflix
# 72   https://en.wikipedia.org/wiki/Nike,_Inc.
# 73   https://en.wikipedia.org/wiki/Nvidia
# 74   https://en.wikipedia.org/wiki/Oracle_Corporation
# 75   https://en.wikipedia.org/wiki/Occidental_Petroleum
# 76   https://en.wikipedia.org/wiki/PepsiCo
# 77   https://en.wikipedia.org/wiki/Pfizer_Inc
# 78   https://en.wikipedia.org/wiki/Procter_%26_Gamble
# 79   https://en.wikipedia.org/wiki/Philip_Morris_International
# 80   https://en.wikipedia.org/wiki/PayPal
# 81   https://en.wikipedia.org/wiki/Qualcomm
# 82   https://en.wikipedia.org/wiki/Raytheon
# 83   https://en.wikipedia.org/wiki/Starbucks
# 84   https://en.wikipedia.org/wiki/Schlumberger
# 85   https://en.wikipedia.org/wiki/Southern_Company
# 86   https://en.wikipedia.org/wiki/Simon_Property_Group
# 87   https://en.wikipedia.org/wiki/AT%26T
# 88   https://en.wikipedia.org/wiki/Target_Corporation
# 89   https://en.wikipedia.org/wiki/Texas_Instruments
# 90   https://en.wikipedia.org/wiki/UnitedHealth_Group
# 91   https://en.wikipedia.org/wiki/Union_Pacific_Corporation
# 92   https://en.wikipedia.org/wiki/United_Parcel_Service
# 93   https://en.wikipedia.org/wiki/U.S._Bancorp
# 94   https://en.wikipedia.org/wiki/United_Technologies
# 95   https://en.wikipedia.org/wiki/Visa_Inc.
# 96   https://en.wikipedia.org/wiki/Verizon_Communications
# 97   https://en.wikipedia.org/wiki/Walgreens_Boots_Alliance
# 98   https://en.wikipedia.org/wiki/Wells_Fargo
# 99   https://en.wikipedia.org/wiki/Walmart
# 100  https://en.wikipedia.org/wiki/ExxonMobil
#
#              matched_company_name     score
# 0    APPLE INC                     1690.0
# 1    ABBVIE INC                    16101.0
# 2    ABBOTT LABORATORIES           1078.0
# 3    ACCENTURE PLC                 143357.0
# 4    ADOBE INC                     12540.0
# 5    ALLERGAN INC                  15708.0
# 6    AMERICAN INTERNATIONAL GROUP  1487.0
# 7    ALLSTATE CORP                 28349.0
# 8    AMGEN INC                     1602.0
# 9    AMAZON.COM INC                64768.0
# 10   AMERICAN EXPRESS CO           1447.0
# 11   BOEING CO                     2285.0
# 12   BANK OF AMERICA CORP          7647.0
# 13   VASCULAR BIOGENICS LTD        21209.0
# 14   BANK OF NEW YORK MELLON CORP  2019.0
# 15   BOOKING HOLDINGS INC          119314.0
# 16   BLACKROCK INC                 124434.0
# 17   BRISTOL-MYERS SQUIBB CO       2403.0
# 18   BERKSHIRE HATHAWAY            2176.0
# 19   CITIGROUP INC                 3243.0
# 20   CATERPILLAR INC               2817.0
# 21   CELGENE CORP                  13599.0
# 22   CHARTER COMMUNICATIONS INC    126136.0
# 23   COLGATE-PALMOLIVE CO          3170.0
# 24   COMCAST CORP                  3226.0
# 25   CAPITAL ONE FINANCIAL CORP    30990.0
# 26   CONOCOPHILLIPS                8549.0
# 27   COSTCO WHOLESALE CORP         29028.0
# 28   CISCO SYSTEMS INC             20779.0
# 29   CVS HEALTH CORP               7241.0
# 30   CHEVRON CORP                  2991.0
# 31   AARON'S INC                   1076.0
# 32   DANAHER CORP                  3735.0
# 33   JOINT CORP (THE)              22082.0
# 34   DOW INC                       34443.0
# 35   DUKE ENERGY CORP              4093.0
# 36   EMERSON ELECTRIC CO           4321.0
# 37   EXELON CORP                   8539.0
# 38   HIGHLAND COPPER COMPANY INC   182979.0
# 39   FACEBOOK INC                  170617.0
# 40   FEDEX CORP                    4598.0
# 41   GENERAL DYNAMICS CORP         5046.0
# 42   GENERAL ELECTRIC CO           5047.0
# 43   GILEAD SCIENCES INC           24856.0
# 44   GENERAL MOTORS CO             5073.0
# 45   ALPHABET INC                  160329.0
# 46   ALPHABET INC                  160329.0
# 47   GOLDMAN SACHS MLP INCM OPPS   19249.0
# 48   HOME DEPOT INC                5680.0
# 49   HONEYWELL INTERNATIONAL INC   1300.0
# 50   ALABAMA GAS CORP              1224.0
# 51   INTELLIGENT COMM ENTR -OLD    3515.0
# 52   JOHNSON & JOHNSON             6266.0
# 53   JPMORGAN CHASE & CO           2968.0
# 54   KRAFT HEINZ CO                5568.0
# 55   KINDER MORGAN INC             6310.0
# 56   COCA-COLA CO                  3144.0
# 57   LILLY (ELI) & CO              6730.0
# 58   LOCKHEED MARTIN CORP          6774.0
# 59   LOWE'S COMPANIES INC          6829.0
# 60   MASTERCARD INC                160225.0
# 61   MCDONALD'S CORP               7154.0
# 62   MONDELEZ INTERNATIONAL INC    142953.0
# 63   MEDTRONIC PLC                 7228.0
# 64   METLIFE INC                   133768.0
# 65   3M CO                         7435.0
# 66   ALTRIA GROUP INC              8543.0
# 67   MERCK & CO                    7257.0
# 68   MORGAN STANLEY                12124.0
# 69   MICROSOFT CORP                12141.0
# 70   NEXTERA ENERGY INC            4517.0
# 71   NETFLIX INC                   147579.0
# 72   ADC TELECOMMUNICATIONS INC    1013.0
# 73   NVIDIA CORP                   117768.0
# 74   ORACLE CORP                   12142.0
# 75   OCCIDENTAL PETROLEUM CORP     8068.0
# 76   PEPSICO INC                   8479.0
# 77   PFIZER INC                    8530.0
# 78   PROCTER & GAMBLE CO           8762.0
# 79   PHILIP MORRIS INTERNATIONAL   179621.0
# 80   PAYPAL HOLDINGS INC           24616.0
# 81   QUALCOMM INC                  24800.0
# 82   RAYTHEON CO                   8972.0
# 83   STARBUCKS CORP                25434.0
# 84   SCHLUMBERGER LTD              9465.0
# 85   COLUMBUS SOUTHERN POWER CORP  3210.0
# 86   SIMON PROPERTY GROUP INC      29389.0
# 87   AT&T INC                      9899.0
# 88   TARGET CORP                   3813.0
# 89   TEXAS INSTRUMENTS INC         10499.0
# 90   UNITEDHEALTH GROUP INC        10903.0
# 91   UNION GAS LTD                 10862.0
# 92   UNITED PARCEL SERVICE INC     10920.0
# 93   U S BANCORP                   4723.0
# 94   UNITED TECHNOLOGIES CORP      10983.0
# 95   VISA INC                      179534.0
# 96   VERIZON COMMUNICATIONS INC    2136.0
# 97   WALGREENS BOOTS ALLIANCE INC  11264.0
# 98   WELLS FARGO & CO              8007.0
# 99   WALMART INC                   11259.0
# 100  EXXON MOBIL CORP              4503.0

# %%
# Exporting to csv
pd_firms.to_csv('task1_solution_Suraj_Kumar.csv',index = False)

# %% [markdown]
# ## Task 2: Apple Inc and Intel 10-K Form study

# %% [markdown]
#  Assumping that Fiscal year means the year in which the fiscal ended.
#
#  * For Apple, fiscal year 2014 duration is from Oct 2013 to Sep 2014 and
#  * for Intel, fiscal Year 2014 is from Jan 2014 to Dec 2014

# %%
# Listing the files_url needed to process the records
apple_2014 = "https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm"
apple_2015 = "https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/d17062d10k.htm"
apple_2016 = "https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/a201610-k9242016.htm"
apple_2017 = "https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/a10-k20179302017.htm"
apple_2018 = "https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm"


# Intel
intel_2014 = "https://www.sec.gov/Archives/edgar/data/50863/000005086315000015/a10kdocument12272014.htm"
intel_2015 = "https://www.sec.gov/Archives/edgar/data/50863/000005086316000105/a10kdocument12262015q4.htm"
intel_2016 = "https://www.sec.gov/Archives/edgar/data/50863/000005086317000012/a10kdocument12312016q4.htm"
intel_2017 = "https://www.sec.gov/Archives/edgar/data/50863/000005086318000007/a12302017q4-10kdocument.htm"
intel_2018 = "https://www.sec.gov/Archives/edgar/data/50863/000005086319000007/a12292018q4-10kdocument.htm"

# %%
apple_10k = [apple_2014, apple_2015, apple_2016, apple_2017, apple_2018]
intel_10k = [intel_2014, intel_2015, intel_2016, intel_2017, intel_2018]

# %%
# Starting empty dic to store the parameters of the request retrival package
ten_k_dict = {}
# Retrving the data using request package and using Beautiful soup on it
for ten_k in (apple_10k + intel_10k):
    print(ten_k)
    r = requests.get(ten_k)
    
    #Storing the results
    ten_k_dict[ten_k] = {'status_code':r.status_code,'soup': BeautifulSoup(r.text)}
# Out:
# https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm
# https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/d17062d10k.htm
# https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/a201610-k9242016.htm
# https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/a10-k20179302017.htm
# https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm
# https://www.sec.gov/Archives/edgar/data/50863/000005086315000015/a10kdocument12272014.htm
# https://www.sec.gov/Archives/edgar/data/50863/000005086316000105/a10kdocument12262015q4.htm
# https://www.sec.gov/Archives/edgar/data/50863/000005086317000012/a10kdocument12312016q4.htm
# https://www.sec.gov/Archives/edgar/data/50863/000005086318000007/a12302017q4-10kdocument.htm
# https://www.sec.gov/Archives/edgar/data/50863/000005086319000007/a12292018q4-10kdocument.htm

# %%
# Checking the status code of all scraping
for ten_k in (apple_10k + intel_10k):
    ten_k_dict[ten_k]['status_code']
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [markdown]
# ### Task 2- Part 1

# %% [markdown]
# #### Task 2 Part 1 : Apple Analysis

# %%
# Function to do task 2 part 1 
def risk_factor_section_stats_generator(company, company_url_list, 
                                        risk_factor_section_start_string,
                                        risk_factor_section_stop_string,
                                        year_list = ['2014','2015','2016','2017','2018']):
    """
    company is company name 
    company_url_list is company url list as defined earliar
    risk_factor_section_start_string is string pattern to identify the beginning of risk section
    risk_factor_section_stop_string is to identify the end of risk section
    year list is names of year of url
    
    """
    # Creating the Dataframe to input results
    risk_factor_section_stats = pd.DataFrame(columns=['company',"year",
                                                      "risk_section_word_length",
                                                      "competition_count"])

    # Looking at one soup
    for i in range(len(year_list)):

        #Printing the year
        #print('The year is {}'.format(year_list[i]))

        # Extracing the soup
        soup = ten_k_dict[company_url_list[i]]['soup']

        # Extracting the p tags
        soup_tags = soup.find_all('p')

        if(len(soup_tags) == 0): # This conditional statment is put here to account for 
            #change in html tag structure starting from year 2016 from p to div
            soup_tags = soup.find_all('div')

        # Extracting paragraphs from these p tags
        soup_paragraphs = [par.get_text().rstrip() for par in soup_tags]

        # Extracting the starting and ending paragraph number of risk section
        for j in range(len(soup_paragraphs)):
            if(  soup_paragraphs[j].find(risk_factor_section_start_string) != -1 ) :
                start_paragraph_number = j
                #print('Starting Paragraph No is {0}'.format(start_paragraph_number))

            if( soup_paragraphs[j].find(risk_factor_section_stop_string) != -1):
                end_paragraph_number = j
                #print('Ending Paragraph No is {0}'.format(end_paragraph_number))

        # Intitiating variable to store risk section content.
        risk_section = ''
        for paragraph in soup_paragraphs[start_paragraph_number:end_paragraph_number]:
            #print(paragraph)
            risk_section = risk_section + ' ' + paragraph

        # Counting the number of words in risk section
        risk_section_words = risk_section.split()
        risk_section_number_of_words = len(risk_section_words)
        #print(risk_section_number_of_words)

        # Counting the number of times the competition repeats in risk section
        risk_section_no_period = risk_section.replace("."," ")  # minor modification to replace period
        competition_count = risk_section_no_period.count('competition') # assuming that we are only searching for "competition" and not "Competition"
        #print(competition_count)

        # Writing the risk section to txt file
        file_name = company + "_" + year_list[i] + ".txt"
        #print(file_name)
        file1 = open(file_name,"w",encoding='utf-8')
        file1.write(risk_section)
        file1.close()

        # Setting the values to a dataframe
        risk_factor_section_stats.at[i,"company"] = company
        risk_factor_section_stats.at[i,"year"] = year_list[i]
        risk_factor_section_stats.at[i,"risk_section_word_length"] = risk_section_number_of_words
        risk_factor_section_stats.at[i,"competition_count"] = competition_count

    return(risk_factor_section_stats)

# %%
risk_factor_section_stats_apple = risk_factor_section_stats_generator("apple",
                                                                      apple_10k,
                                                                      risk_factor_section_start_string = "The following discussion of risk factors contains forward-looking statements" ,
                                                                      risk_factor_section_stop_string = "headquarters are located in Cupertino, California")
risk_factor_section_stats_apple
# Out:
#   company  year risk_section_word_length competition_count
# 0  apple   2014  7710                     8
# 1  apple   2015  7765                     8
# 2  apple   2016  7680                     8
# 3  apple   2017  7779                     8
# 4  apple   2018  8082                     9

# %%
# doing the similar thing for intel
risk_factor_section_stats_intel_2014_to_2016 = risk_factor_section_stats_generator("intel",
                                                                      intel_10k,
                                                                      risk_factor_section_start_string = "The following risks could materially and adversely" ,
                                                                      risk_factor_section_stop_string = "UNRESOLVED STAFF COMMENTS",
                                                                      year_list= ['2014','2015','2016'])
risk_factor_section_stats_intel_2014_to_2016
# Out:
#   company  year risk_section_word_length competition_count
# 0  intel   2014  5824                     5
# 1  intel   2015  5833                     5
# 2  intel   2016  6406                     5

# %%
# Due to change in Intel 10k Form HTML strucure so doing it differently for year 2017 and 2018
intel_10k_2017_2018 = [intel_2017,intel_2018]

risk_factor_section_stats_intel_2017_2018 = risk_factor_section_stats_generator("intel",
                                                                      intel_10k_2017_2018,
                                                                      risk_factor_section_start_string = "The following risks could materially and adversely" ,
                                                                      risk_factor_section_stop_string = "In addition to disclosing financial results in accordance with GAAP",
                                                                      year_list= ['2017','2018'])
risk_factor_section_stats_intel_2017_2018
# Out:
#   company  year risk_section_word_length competition_count
# 0  intel   2017  6669                     5
# 1  intel   2018  8458                     6

# %%
## Now combining all the datasets in one data
risk_factor_section_stats = pd.concat([risk_factor_section_stats_apple,
                                         risk_factor_section_stats_intel_2014_to_2016,
                                        risk_factor_section_stats_intel_2017_2018])

# %%
# Printing and writing to csv the results
risk_factor_section_stats
risk_factor_section_stats.to_csv("task2_part1_risk_factor_section_stats.csv",index=False)
# Out:
#   company  year risk_section_word_length competition_count
# 0  apple   2014  7710                     8
# 1  apple   2015  7765                     8
# 2  apple   2016  7680                     8
# 3  apple   2017  7779                     8
# 4  apple   2018  8082                     9
# 0  intel   2014  5824                     5
# 1  intel   2015  5833                     5
# 2  intel   2016  6406                     5
# 0  intel   2017  6669                     5
# 1  intel   2018  8458                     6

# %% [markdown]
# ### Task 2 Part 2 NLTK Analsys

# %%
# Defining the stop word
stop_words = set(stopwords.words('english')) 

# Setting up search word to find in filtered_sentence
search_word = 'patent'

# Settup the dataframe
patent_match_df = pd.DataFrame(columns=['file_name','word_preceding','occurence_found','word_following'])
i = 0 # setting the first row of the dataframe 

for company in ['apple','intel']:
    for year in ['2014','2015','2016','2017','2018']:
        
        ## importing the txt file
        file_name = company + "_" + year + ".txt"
        print(file_name)
        #file_name = "apple_2014.txt"
        
        file_object = open(file_name,"r",encoding='utf-8')
        data = file_object.read().replace('\n', ' ')
        data_no_period = data.replace("."," ")
        
        # Tokenings
        word_tokens = word_tokenize(data_no_period) 

        # Checking the length of word_tokens
        len(word_tokens)

        # Removing the stop words
        filtered_sentence = [w for w in word_tokens if not w in stop_words] 

        # Checking the length after remving stop words
        len(filtered_sentence)

        #chekcing
        #word_tokens[0:20]

        #checking
        #filtered_sentence[0:20]
        for j in range(len(filtered_sentence)):
            if (filtered_sentence[j].lower().find(search_word) != -1): # condtion to check the match
                patent_match_df.at[i,'file_name'] = file_name
                patent_match_df.at[i,'word_preceding'] = filtered_sentence[j-1]
                patent_match_df.at[i,'occurence_found'] = filtered_sentence[j]
                patent_match_df.at[i,'word_following'] = filtered_sentence[j+1]
                i = i + 1
# Out:
# apple_2014.txt
# 8239
# 5493
# apple_2015.txt
# 8301
# 5527
# apple_2016.txt
# 8522
# 5684
# apple_2017.txt
# 8643
# 5761
# apple_2018.txt
# 9007
# 6023
# intel_2014.txt
# 6373
# 4165
# intel_2015.txt
# 6398
# 4198
# intel_2016.txt
# 7050
# 4650
# intel_2017.txt
# 7332
# 4928
# intel_2018.txt
# 9315
# 6231

# %%
patent_match_df.shape
# Out:
# (98, 4)

# %%
patent_match_df
patent_match_df.to_csv("task2_part2_patent_match.csv",index = False)
# Out:
#          file_name word_preceding occurence_found word_following
# 0   apple_2014.txt  number         patents         copyrights
# 1   apple_2014.txt  numerous       patents         ,
# 2   apple_2014.txt  allegations    patent          infringement
# 3   apple_2014.txt  ,              patent          holding
# 4   apple_2014.txt  monetize       patents         purchased
# 5   apple_2014.txt  significant    patent          portfolios
# 6   apple_2014.txt  number         patent          claims
# 7   apple_2014.txt  validity       patents         intellectual
# 8   apple_2014.txt  one            patents         intellectual
# 9   apple_2015.txt  number         patents         copyrights
# 10  apple_2015.txt  numerous       patents         ,
# 11  apple_2015.txt  allegations    patent          infringement
# 12  apple_2015.txt  ,              patent          holding
# 13  apple_2015.txt  monetize       patents         purchased
# 14  apple_2015.txt  significant    patent          portfolios
# 15  apple_2015.txt  number         patent          claims
# 16  apple_2015.txt  validity       patents         intellectual
# 17  apple_2015.txt  one            patents         intellectual
# 18  apple_2016.txt  number         patents         copyrights
# 19  apple_2016.txt  numerous       patents         ,
# 20  apple_2016.txt  allegations    patent          infringement
# 21  apple_2016.txt  ,              patent          holding
# 22  apple_2016.txt  monetize       patents         purchased
# 23  apple_2016.txt  significant    patent          portfolios
# 24  apple_2016.txt  number         patent          claims
# 25  apple_2016.txt  validity       patents         intellectual
# 26  apple_2016.txt  one            patents         intellectual
# 27  apple_2017.txt  number         patents         copyrights
# 28  apple_2017.txt  numerous       patents         ,
# 29  apple_2017.txt  allegations    patent          infringement
# 30  apple_2017.txt  number         patent          claims
# 31  apple_2017.txt  technology     patent-holding  companies
# 32  apple_2017.txt  assert         patents         seek
# 33  apple_2017.txt  allegations    patent          infringement
# 34  apple_2018.txt  number         patents         copyrights
# 35  apple_2018.txt  numerous       patents         ,
# 36  apple_2018.txt  allegations    patent          infringement
# 37  apple_2018.txt  number         patent          claims
# 38  apple_2018.txt  technology     patent-holding  companies
# 39  apple_2018.txt  assert         patents         seek
# 40  apple_2018.txt  allegations    patent          infringement
# 41  intel_2014.txt  regard         patents         ,
# 42  intel_2014.txt  use            patent          rights
# 43  intel_2014.txt  license        patents         settle
# 44  intel_2014.txt  licenses       patents         ,
# 45  intel_2014.txt  exhaust        patent          rights
# 46  intel_2014.txt  license        patents         companies
# 47  intel_2014.txt  licenses       patents         little
# 48  intel_2014.txt  certain        patents         others
# 49  intel_2014.txt  protecting     patents         may
# 50  intel_2014.txt  acquired       patent          portfolios
# 51  intel_2014.txt  licensing      patents         An
# 52  intel_2015.txt  regard         patents         ,
# 53  intel_2015.txt  use            patent          rights
# 54  intel_2015.txt  license        patents         settle
# 55  intel_2015.txt  licenses       patents         ,
# 56  intel_2015.txt  exhaust        patent          rights
# 57  intel_2015.txt  license        patents         companies
# 58  intel_2015.txt  licenses       patents         little
# 59  intel_2015.txt  certain        patents         others
# 60  intel_2015.txt  protecting     patents         may
# 61  intel_2015.txt  acquired       patent          portfolios
# 62  intel_2015.txt  licensing      patents         An
# 63  intel_2016.txt  regard         patents         ,
# 64  intel_2016.txt  use            patent          rights
# 65  intel_2016.txt  license        patents         settle
# 66  intel_2016.txt  licenses       patents         ,
# 67  intel_2016.txt  exhaust        patent          rights
# 68  intel_2016.txt  license        patents         companies
# 69  intel_2016.txt  licenses       patents         little
# 70  intel_2016.txt  certain        patents         others
# 71  intel_2016.txt  protecting     patents         may
# 72  intel_2016.txt  acquired       patent          portfolios
# 73  intel_2016.txt  licensing      patents         An
# 74  intel_2017.txt  regard         patents         ,
# 75  intel_2017.txt  use            patent          rights
# 76  intel_2017.txt  license        patents         settle
# 77  intel_2017.txt  licenses       patents         ,
# 78  intel_2017.txt  exhaust        patent          rights
# 79  intel_2017.txt  license        patents         companies
# 80  intel_2017.txt  licenses       patents         little
# 81  intel_2017.txt  certain        patents         others
# 82  intel_2017.txt  protecting     patents         may
# 83  intel_2017.txt  aggregated     patents         acquired
# 84  intel_2017.txt  large          patent          portfolio
# 85  intel_2017.txt  licensing      patents         An
# 86  intel_2018.txt  regard         patents         ,
# 87  intel_2018.txt  use            patent          rights
# 88  intel_2018.txt  license        patents         settle
# 89  intel_2018.txt  licenses       patents         ,
# 90  intel_2018.txt  exhaust        patent          rights
# 91  intel_2018.txt  license        patents         companies
# 92  intel_2018.txt  licenses       patents         little
# 93  intel_2018.txt  certain        patents         others
# 94  intel_2018.txt  protecting     patents         may
# 95  intel_2018.txt  aggregated     patents         acquired
# 96  intel_2018.txt  large          patent          portfolio
# 97  intel_2018.txt  licensing      patents         An

# %% [markdown]
# # Thanks Note
#
# Thanks Prof Gallemore, for giving this assignment. I learnt a lot about web-scraping from this. I am happy that I am able to complete the task in approximately 13 hrs starting from sctrach on webscrapping and HTML knowledge.
